# %% [markdown]
# # Crawling the Job Market
# Authors: Sameer NANDIKAR(u1010576), Byron ENG <br>
# CS 5963 / MATH 3900 <br>
# email id: sameer.nandikar@gmail.com
#           ; byron.eng@gmail.com

# %% [markdown]
# ## Background and Motivation
# We the authors of this project will be graduating in near future. Thus we need to look for jobs in our respective fields (which in our case is Mechanical Engineering and Atmospheric Sciences) or continue academics in a well-informed direction for better job opportunities. In either case a comperhensive analysis of the job market depicting trends and classifications can be really benificial.
#
# Motivation for this project comes from some obstacles encounterd in the job search, some of which we have tried to elaborate here. Though there are many job search websites which provide a plethora of information about jobs available, one can not draw useful conclusions about the job market such as density of reasearch and development jobs for a mechanical engineer in medical device sector in state of Utah, without analysis of that information. In addition to that, job openings in most of the industries related to Mechanical Engineering are requirement oriented and have very short lead times for joining thus it would be interesting to see if there are any trends in job openings and use the information to benefit the job seekers to decide when to graduate. These are just few queries among other problems we intend to solve.
#
# One more aspect of this project includes classification of jobs according to job function and sector, which will help an aspiring Graduate student to take an informed decision to select an area of interest (such as designing, manufacturing, robotics, energy systems).

# %% [markdown]
# ## Project Objectives
# This project aims to be a tool for anyone entering the job market. The key objective of this project is the analysis of the job market which will include but will not be limited to
# - Geospatial density of jobs
# - Pay rates vs. experience level
# - Pay rates vs. education level
# - Classification of jobs on basis of sector (e.g.aerospace, automobile, medical device, energy, mining equipment etc)
# - Classification of jobs on basis of job function (e.g. production, quality control, design, research and development etc)
# - Annual trend of job openings for different sectors and job functions for different states

# %% [markdown]
# ## Data
#
# At this stage we are looking from which websites we can scrap the data and which websites have APIs. Given below is the information of our current options
#
# ### Inventory of data sources
#
# |Site|Comments|Allowed (scraping)|Disallowed (scraping)|API|API Reference
# |----|--------|:-----:|:--------:|---
# |Glassdoor.com|Has mostly disallows. Because we are going to be using the search, I don't think we are allowed to crawl.||x|Yes|https://www.glassdoor.com/developer/index.htm (access requested)
# |usajobs.gov|Disallows scripts||x|Yes|https://developer.usajobs.gov/API-Reference
# |dice.com|Disallows jobsearch||x|Yes|http://www.dice.com/common/content/util/apidoc/jobsearch.html
# |snagajob.com|Disallows basically everything||x|No|-|
# |simplyhired.com|Links to other sites, disallows job details but not job SEARCH||x|No|-|
# |careerbuilder.com|Disallows everything unless you're the googlebot||x|Yes|Requested key
# |careerinfonet.org|There's a lot that is disallowed, but I don't see anything that is clearly disallowing what we aim to do. Worth another look.||x|No|-|
# |indeed.com|Mostly disallows everything ||x|Yes|Requested key|
# |monster.com|Mostly disallows evferything||x|Yes|Regestration is required for access which is in progress|
# |linkedin.com|Allows scraping with permission||x|Yes|https://api.linkedin.com/v1/people/~?format=json (but an access token is required which is requested)|
# |bls.gov|||x|Yes|http://www.bls.gov/developers/api_python.htm

# %% [markdown]
# ## Data Processing
#
# In addition to APIs, we will keep html scraping as an option. An html of a typical job search website has list of jobs and their links. A dataframe will be created by extracting the information about the jobs from the html page and from nested url links. We will use beautifulsoup and CSS selectors for this purpose. We expect much of the effort to be in data extraction and especially in data clean up because information about the jobs entered may not follow same format most of the times as it is entered by different users. We will be using classification methods to classify the jobs by the desired metrics (ie. degree requirement). Also we need to filter out the features which are out of our present scope of study.

# %% [markdown]
# ## Exploratory Analysis
#
# At this stage we intend to observe trends of job openings geographically as well as annually. Thus we will use scatter plots and other tools we have learned in this class for visualizations. Heuristic approach also seems appropriate for given purposes. For classification we intend to use SVM, Decision trees and k-NN and based on kind of results we get we will select best suitable method.

# %% [markdown]
# ## Analysis Methodlogy
#
# We will first analyze the aggregated data to see geographical and annual trends. Also we will observe the effects of attributes over salary e.g. Pay rates vs. experience level and Pay rates vs. education level.
#
# Secondly for classification purposes based on the size of the data we get from one website we will either divide one website's data into training and test data or use data from one website as training and data from another website as test data. We will use classification methods enlisted above and select the best suitable one to visualize the data in scatter plots

# %% [markdown]
# ## Project Schedule
#
# We have 5 weeks till the presentation date
#
# Week 1 - Data acquisition and cleaning
#
# Week 2 - Data processing
#
# Week 3 and 4 - Exploratory analysis
#
# Week 5 - Preperation for the Presentation

# %% [markdown]
# # Data acquisition and cleaning

# %%
import requests 
import urllib.request
import os.path
city = "houston"
state = "tx"
keyword = "mechanical"
url = "http://api.indeed.com/ads/apisearch?publisher=336274463762899&format=json&q="+keyword+"&l="+city+"%2C+"+state+"&sort=&radius=150&st=&jt=fulltime&start=&limit=5000&fromage=&filter=&latlong=1&co=us&chnl=&userip=1.2.3.4&useragent=Mozilla/%2F4.0%28Firefox%29&v=2"
# here it's already a local operation
response = requests.get(url)

response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'{"version":2,"query":"mechanical","location":"houston, tx","paginationPayload":"","radius":150,"dupefilter":true,"highlight":true,"totalResults":3629,"start":1,"end":25,"pageNumber":0,"results":[{"jobtitle":"SolidWorks Drafter","company":"Transformer Protector Corp.","city":"Humble","state":"TX","country":"US","formattedLocation":"Humble, TX","source":"Indeed","date":"Mon, 07 Nov 2016 01:51:13 GMT","snippet":"Solidworks <b>Mechanical</b> Drafter. <b>Mechanical</b> and manufacturing constraints knowledge. Additional responsibilities to create or update the <b>mechanical</b> drawings,...","url":"http://www.indeed.com/viewjob?jk=4ba9f2aa57c2a26f&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih","onmousedown":"indeed_clk(this,\'8974\');","latitude":29.993994,"longitude":-95.24721,"jobkey":"4ba9f2aa57c2a26f","sponsored":false,"expired":false,"indeedApply":true,"formattedLocationFull":"Humble, TX 77338","formattedRelativeTime":"11 days ago","stations":""},{"jobtitle":"Integration Engineer \xe2\x80\x93 Entry level","company":"Barrios Technology, Ltd.","city":"Houston","state":"TX","country":"US","formattedLocation":"Houston, TX","source":"Barrios Technology, Ltd.","date":"Mon, 14 Nov 2016 23:08:36 GMT","snippet":"BS degree in Aerospace engineering, Systems engineering or <b>Mechanical</b> engineering from an accredited college or university....","url":"http://www.indeed.com/viewjob?jk=f2bc435d2258ef82&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih","onmousedown":"indeed_clk(this,\'8974\');","latitude":29.552198,"longitude":-95.09341,"jobkey":"f2bc435d2258ef82","sponsored":false,"expired":false,"indeedApply":false,"formattedLocationFull":"Houston, TX 77058","formattedRelativeTime":"3 days ago","stations":""},{"jobtitle":"Mechanical Engineer - AMC.ENG.","company":"AmeriMex Motor & Controls, LLC.","city":"Houston","state":"TX","country":"US","formattedLocation":"Houston, TX","source":"Indeed","date":"Mon, 14 Nov 2016 17:51:38 GMT","snippet":"Develops <b>mechanical</b> and electromechanical products by studying customer requirements; Evaluates <b>mechanical</b> and electromechanical systems and products by...","url":"http://www.indeed.com/viewjob?jk=4f425dc87dd202fe&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih","onmousedown":"indeed_clk(this,\'8974\');","latitude":29.760988,"longitude":-95.36264,"jobkey":"4f425dc87dd202fe","sponsored":false,"expired":false,"indeedApply":true,"formattedLocationFull":"Houston, TX","formattedRelativeTime":"3 days ago","stations":""},{"jobtitle":"Mechanical Engineer","company":"ITW","city":"Houston","state":"TX","country":"US","formattedLocation":"Houston, TX","source":"ITW","date":"Mon, 14 Nov 2016 17:37:22 GMT","snippet":"Resolve structural, <b>mechanical</b>, and development issues. Develop <b>mechanical</b> prototypes to determine design feasibility....","url":"http://www.indeed.com/viewjob?jk=ea33c92ffc241264&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih","onmousedown":"indeed_clk(this,\'8974\');","latitude":29.760988,"longitude":-95.36264,"jobkey":"ea33c92ffc241264","sponsored":false,"expired":false,"indeedApply":false,"formattedLocationFull":"Houston, TX","formattedRelativeTime":"4 days ago","stations":""},{"jobtitle":"Mechanical Engineer","company":"FlowBelow Aero, Inc","city":"Austin","state":"TX","country":"US","formattedLocation":"Austin, TX","source":"Indeed","date":"Thu, 27 Oct 2016 20:49:05 GMT","snippet":"Bachelor\xe2\x80\x99s degree or higher in <b>mechanical</b>, aerospa ...

# %%
response_j = response.content.decode("utf-8")
print(response_j)
# Out:
# {"version":2,"query":"mechanical","location":"houston, tx","paginationPayload":"","radius":150,"dupefilter":true,"highlight":true,"totalResults":3629,"start":1,"end":25,"pageNumber":0,"results":[{"jobtitle":"SolidWorks Drafter","company":"Transformer Protector Corp.","city":"Humble","state":"TX","country":"US","formattedLocation":"Humble, TX","source":"Indeed","date":"Mon, 07 Nov 2016 01:51:13 GMT","snippet":"Solidworks <b>Mechanical</b> Drafter. <b>Mechanical</b> and manufacturing constraints knowledge. Additional responsibilities to create or update the <b>mechanical</b> drawings,...","url":"http://www.indeed.com/viewjob?jk=4ba9f2aa57c2a26f&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih","onmousedown":"indeed_clk(this,'8974');","latitude":29.993994,"longitude":-95.24721,"jobkey":"4ba9f2aa57c2a26f","sponsored":false,"expired":false,"indeedApply":true,"formattedLocationFull":"Humble, TX 77338","formattedRelativeTime":"11 days ago","stations":""},{"jobtitle":"Integration Engineer – Entry level","company":"Barrios Technology, Ltd.","city":"Houston","state":"TX","country":"US","formattedLocation":"Houston, TX","source":"Barrios Technology, Ltd.","date":"Mon, 14 Nov 2016 23:08:36 GMT","snippet":"BS degree in Aerospace engineering, Systems engineering or <b>Mechanical</b> engineering from an accredited college or university....","url":"http://www.indeed.com/viewjob?jk=f2bc435d2258ef82&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih","onmousedown":"indeed_clk(this,'8974');","latitude":29.552198,"longitude":-95.09341,"jobkey":"f2bc435d2258ef82","sponsored":false,"expired":false,"indeedApply":false,"formattedLocationFull":"Houston, TX 77058","formattedRelativeTime":"3 days ago","stations":""},{"jobtitle":"Mechanical Engineer - AMC.ENG.","company":"AmeriMex Motor & Controls, LLC.","city":"Houston","state":"TX","country":"US","formattedLocation":"Houston, TX","source":"Indeed","date":"Mon, 14 Nov 2016 17:51:38 GMT","snippet":"Develops <b>mechanical</b> and electromechanical products by studying customer requirements; Evaluates <b>mechanical</b> and electromechanical systems and products by...","url":"http://www.indeed.com/viewjob?jk=4f425dc87dd202fe&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih","onmousedown":"indeed_clk(this,'8974');","latitude":29.760988,"longitude":-95.36264,"jobkey":"4f425dc87dd202fe","sponsored":false,"expired":false,"indeedApply":true,"formattedLocationFull":"Houston, TX","formattedRelativeTime":"3 days ago","stations":""},{"jobtitle":"Mechanical Engineer","company":"ITW","city":"Houston","state":"TX","country":"US","formattedLocation":"Houston, TX","source":"ITW","date":"Mon, 14 Nov 2016 17:37:22 GMT","snippet":"Resolve structural, <b>mechanical</b>, and development issues. Develop <b>mechanical</b> prototypes to determine design feasibility....","url":"http://www.indeed.com/viewjob?jk=ea33c92ffc241264&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih","onmousedown":"indeed_clk(this,'8974');","latitude":29.760988,"longitude":-95.36264,"jobkey":"ea33c92ffc241264","sponsored":false,"expired":false,"indeedApply":false,"formattedLocationFull":"Houston, TX","formattedRelativeTime":"4 days ago","stations":""},{"jobtitle":"Mechanical Engineer","company":"FlowBelow Aero, Inc","city":"Austin","state":"TX","country":"US","formattedLocation":"Austin, TX","source":"Indeed","date":"Thu, 27 Oct 2016 20:49:05 GMT","snippet":"Bachelor’s degree or higher in <b>mechanical</b>, aerospace or automotive engineering. Th ...

# %%
import json
response_d = json.loads(response_j)
print(type(response_d))
response_d
# Out:
# <class 'dict'>
# {'dupefilter': True,
#  'end': 25,
#  'highlight': True,
#  'location': 'houston, tx',
#  'pageNumber': 0,
#  'paginationPayload': '',
#  'query': 'mechanical',
#  'radius': 150,
#  'results': [{'city': 'Humble',
#    'company': 'Transformer Protector Corp.',
#    'country': 'US',
#    'date': 'Mon, 07 Nov 2016 01:51:13 GMT',
#    'expired': False,
#    'formattedLocation': 'Humble, TX',
#    'formattedLocationFull': 'Humble, TX 77338',
#    'formattedRelativeTime': '11 days ago',
#    'indeedApply': True,
#    'jobkey': '4ba9f2aa57c2a26f',
#    'jobtitle': 'SolidWorks Drafter',
#    'latitude': 29.993994,
#    'longitude': -95.24721,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': 'Solidworks <b>Mechanical</b> Drafter. <b>Mechanical</b> and manufacturing constraints knowledge. Additional responsibilities to create or update the <b>mechanical</b> drawings,...',
#    'source': 'Indeed',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=4ba9f2aa57c2a26f&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'},
#   {'city': 'Houston',
#    'company': 'Barrios Technology, Ltd.',
#    'country': 'US',
#    'date': 'Mon, 14 Nov 2016 23:08:36 GMT',
#    'expired': False,
#    'formattedLocation': 'Houston, TX',
#    'formattedLocationFull': 'Houston, TX 77058',
#    'formattedRelativeTime': '3 days ago',
#    'indeedApply': False,
#    'jobkey': 'f2bc435d2258ef82',
#    'jobtitle': 'Integration Engineer – Entry level',
#    'latitude': 29.552198,
#    'longitude': -95.09341,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': 'BS degree in Aerospace engineering, Systems engineering or <b>Mechanical</b> engineering from an accredited college or university....',
#    'source': 'Barrios Technology, Ltd.',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=f2bc435d2258ef82&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'},
#   {'city': 'Houston',
#    'company': 'AmeriMex Motor & Controls, LLC.',
#    'country': 'US',
#    'date': 'Mon, 14 Nov 2016 17:51:38 GMT',
#    'expired': False,
#    'formattedLocation': 'Houston, TX',
#    'formattedLocationFull': 'Houston, TX',
#    'formattedRelativeTime': '3 days ago',
#    'indeedApply': True,
#    'jobkey': '4f425dc87dd202fe',
#    'jobtitle': 'Mechanical Engineer - AMC.ENG.',
#    'latitude': 29.760988,
#    'longitude': -95.36264,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': 'Develops <b>mechanical</b> and electromechanical products by studying customer requirements; Evaluates <b>mechanical</b> and electromechanical systems and products by...',
#    'source': 'Indeed',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=4f425dc87dd202fe&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'},
#   {'city': 'Houston',
#    'company': 'ITW',
#    'country': 'US',
#    'date': 'Mon, 14 Nov 2016 17:37:22 GMT',
#    'expired': False,
#    'formattedLocation': 'Houston, TX',
#    'formattedLocationFull': 'Houston, TX',
#    'formattedRelativeTime': '4 days ago',
#    'indeedApply': False,
#    'jobkey': 'ea33c92ffc241264',
#    'jobtitle': 'Mechanical Engineer',
#    'latitude': 29.760988,
#    'longitude': -95.36264,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': 'Resolve structural, <b>mechanical</b>, and development issues. Develop <b>mechanical</b> prototypes to determine design feasibility....',
#    'source': 'ITW',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=ea33c92ffc241264&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'},
#   {'city': 'Austin',
#    'company': 'FlowBelow Aero, Inc',
#    'country': 'US',
#    'date': 'Thu, 27 Oct 2016 20:49:05 GMT',
#    'expired': False,
#    'formattedLocation': 'Austin, TX',
#    'formattedLocationFull': 'Austin, TX',
#    'formattedRelativeTime': '21 days ago',
#    'indeedApply': True,
#    'jobkey': '78f13f1b001d5aeb',
#    'jobtitle': 'Mechanical Engineer',
#    'latitude': 30.266483,
#    'longitude': -97.74176,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': 'Bachelor’s degree or higher in <b>mechanical</b>, aerospace or automotive engineering. This position is for an engineer with experience designing <b>mechanical</b> components...',
#    'source': 'Indeed',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=78f13f1b001d5aeb&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'},
#   {'city': 'Austin',
#    'company': 'University of Texas at Austin',
#    'country': 'US',
#    'date': 'Tue, 30 Aug 2016 20:21:20 GMT',
#    'expired': False,
#    'formattedLocation': 'Austin, TX',
#    'formattedLocationFull': 'Austin, TX',
#    'formattedRelativeTime': '30+ days ago',
#    'indeedApply': False,
#    'jobkey': '522a136536b77db0',
#    'jobtitle': 'Manager',
#    'latitude': 30.266483,
#    'longitude': -97.74176,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': 'May work around electrical and <b>mechanical</b> hazards. Supervise and manage the day to day operation and maintenance of the Nuclear Regulatory Commission Licensed...',
#    'source': 'University of Texas at Austin',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=522a136536b77db0&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'},
#   {'city': 'Houston',
#    'company': 'Weatherford',
#    'country': 'US',
#    'date': 'Mon, 14 Nov 2016 21:16:52 GMT',
#    'expired': False,
#    'formattedLocation': 'Houston, TX',
#    'formattedLocationFull': 'Houston, TX 77060',
#    'formattedRelativeTime': '3 days ago',
#    'indeedApply': False,
#    'jobkey': 'cc1cad3fda744fa2',
#    'jobtitle': 'MECHANICAL TECHNICIAN',
#    'latitude': 29.925825,
#    'longitude': -95.39011,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': 'To design, procure, and assemble parts for testing <b>mechanical</b> prototype assemblies per application. Able to read and interpret <b>mechanical</b> assembly prints and...',
#    'source': 'Weatherford',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=cc1cad3fda744fa2&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'},
#   {'city': 'Houston',
#    'company': 'Sinopec Tech Houston LLC.',
#    'country': 'US',
#    'date': 'Thu, 27 Oct 2016 22:58:38 GMT',
#    'expired': False,
#    'formattedLocation': 'Houston, TX',
#    'formattedLocationFull': 'Houston, TX',
#    'formattedRelativeTime': '21 days ago',
#    'indeedApply': True,
#    'jobkey': 'b0ca93b1ec3c1f40',
#    'jobtitle': 'Mechanical Design Engineer - MWD/LWD Telemetry',
#    'latitude': 29.760988,
#    'longitude': -95.36264,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': '<b>Mechanical</b> Design Engineer:. <b>Mechanical</b> Design Engineer – MWD/LWD Telemetry*. Master’s Degree in <b>Mechanical</b> Engineering is strongly preferred....',
#    'source': 'Indeed',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=b0ca93b1ec3c1f40&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'},
#   {'city': 'Austin',
#    'company': 'Glumac',
#    'country': 'US',
#    'date': 'Thu, 17 Nov 2016 17:33:55 GMT',
#    'expired': False,
#    'formattedLocation': 'Austin, TX',
#    'formattedLocationFull': 'Austin, TX',
#    'formattedRelativeTime': '1 day ago',
#    'indeedApply': False,
#    'jobkey': 'e67c9c572b0b5132',
#    'jobtitle': 'Plumbing Designer',
#    'latitude': 30.266483,
#    'longitude': -97.74176,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': 'Bachelors degree in <b>mechanical</b> engineering, a related field or equivalent industry design experience....',
#    'source': 'Glumac',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=e67c9c572b0b5132&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'},
#   {'city': 'Austin',
#    'company': 'Hyatt',
#    'country': 'US',
#    'date': 'Wed, 05 Oct 2016 17:02:12 GMT',
#    'expired': False,
#    'formattedLocation': 'Austin, TX',
#    'formattedLocationFull': 'Austin, TX',
#    'formattedRelativeTime': '30+ days ago',
#    'indeedApply': False,
#    'jobkey': '25782125b9dd56a3',
#    'jobtitle': 'General Maintenance Engineer - Entry Level- Full-Time',
#    'latitude': 30.266483,
#    'longitude': -97.74176,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': 'A General Maintenance Engineer will also perform some repairs on <b>mechanical</b>, electrical, kitchen, and laundry equipment, requiring some skills and experience in...',
#    'source': 'Hyatt',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=25782125b9dd56a3&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'},
#   {'city': 'Houston',
#    'company': 'Affiliated Engineers, Inc.',
#    'country': 'US',
#    'date': 'Mon, 07 Nov 2016 17:46:16 GMT',
#    'expired': False,
#    'formattedLocation': 'Houston, TX',
#    'formattedLocationFull': 'Houston, TX 77046',
#    'formattedRelativeTime': '10 days ago',
#    'indeedApply': False,
#    'jobkey': '1b32a9b373befd86',
#    'jobtitle': 'Mechanical Engineer II',
#    'latitude': 29.732288,
#    'longitude': -95.4327,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': 'We are seeking a <b>Mechanical</b> Engineer II to join our Houston, TX office. Being part of the solution....',
#    'source': 'Affiliated Engineers, Inc.',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=1b32a9b373befd86&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'},
#   {'city': 'Austin',
#    'company': 'Applied Materials Inc.',
#    'country': 'US',
#    'date': 'Mon, 01 Aug 2016 22:57:45 GMT',
#    'expired': False,
#    'formattedLocation': 'Austin, TX',
#    'formattedLocationFull': 'Austin, TX',
#    'formattedRelativeTime': '30+ days ago',
#    'indeedApply': False,
#    'jobkey': 'd832b3b09551f950',
#    'jobtitle': 'Manufacturing Technician I - (T1)',
#    'latitude': 30.266483,
#    'longitude': -97.74176,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': 'Entry-level position with appropriate licenses/training certifications. Has basic skills in an analytical or scientific method or operational process. Works',
#    'source': 'Applied Materials Inc.',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=d832b3b09551f950&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'},
#   {'city': 'Freeport',
#    'company': 'Olin Chlor Alkali',
#    'country': 'US',
#    'date': 'Thu, 06 Oct 2016 10:24:48 GMT',
#    'expired': False,
#    'formattedLocation': 'Freeport, TX',
#    'formattedLocationFull': 'Freeport, TX',
#    'formattedRelativeTime': '30+ days ago',
#    'indeedApply': False,
#    'jobkey': '14779ce923936541',
#    'jobtitle': 'Mechanical Engineer- Maintenance',
#    'latitude': 28.953297,
#    'longitude': -95.35714,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': 'In <b>Mechanical</b> Engineering or Electrical Engineering required. Olin Chlor Alkali Products and Vinyl’s, a division of Olin Corporation, has an opportunity for a...',
#    'source': 'Olin Chlor Alkali',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=14779ce923936541&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'},
#   {'city': 'Houston',
#    'company': 'Nabors Industries',
#    'country': 'US',
#    'date': 'Tue, 01 Nov 2016 23:17:53 GMT',
#    'expired': False,
#    'formattedLocation': 'Houston, TX',
#    'formattedLocationFull': 'Houston, TX 77067',
#    'formattedRelativeTime': '16 days ago',
#    'indeedApply': False,
#    'jobkey': '62edf173de06f2c4',
#    'jobtitle': 'Mechanical Designer III',
#    'latitude': 29.94822,
#    'longitude': -95.42344,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': 'Model <b>mechanical</b> design concepts using 3D Parametric software. <b>Mechanical</b> design principals including machined parts, assemblies, weldment and sheet metal...',
#    'source': 'Nabors Industries',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=62edf173de06f2c4&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'},
#   {'city': 'Houston',
#    'company': 'Chicago Bridge & Iron Company',
#    'country': 'US',
#    'date': 'Sun, 06 Nov 2016 11:08:06 GMT',
#    'expired': False,
#    'formattedLocation': 'Houston, TX',
#    'formattedLocationFull': 'Houston, TX',
#    'formattedRelativeTime': '12 days ago',
#    'indeedApply': False,
#    'jobkey': '9a72287f6e64668c',
#    'jobtitle': 'Principal Mechanical Engineer - Insulation, Coating, and Fireproofing',
#    'latitude': 29.760988,
#    'longitude': -95.36264,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': 'MS Degree in <b>Mechanical</b> Engineering preferred. Bachelors of Science in <b>Mechanical</b> Engineering required. Principal <b>Mechanical</b> Engineer – Insulation, Coating and...',
#    'source': 'Chicago Bridge & Iron Company',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=9a72287f6e64668c&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'},
#   {'city': 'Houston',
#    'company': 'SNC-Lavalin',
#    'country': 'US',
#    'date': 'Fri, 28 Oct 2016 22:42:26 GMT',
#    'expired': False,
#    'formattedLocation': 'Houston, TX',
#    'formattedLocationFull': 'Houston, TX',
#    'formattedRelativeTime': '20 days ago',
#    'indeedApply': False,
#    'jobkey': 'd89dbce7110266cc',
#    'jobtitle': 'Applications Engineer',
#    'latitude': 29.760988,
#    'longitude': -95.36264,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': 'BS degree in <b>Mechanical</b> Engineering or equivalent experience. Applications engineering position that responds to any immediate needs of account managers working...',
#    'source': 'SNC-Lavalin',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=d89dbce7110266cc&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'},
#   {'city': 'Beaumont',
#    'company': 'Burrow Global, LLC',
#    'country': 'US',
#    'date': 'Fri, 18 Nov 2016 14:32:18 GMT',
#    'expired': False,
#    'formattedLocation': 'Beaumont, TX',
#    'formattedLocationFull': 'Beaumont, TX',
#    'formattedRelativeTime': '3 hours ago',
#    'indeedApply': False,
#    'jobkey': '526f1c14c33370d7',
#    'jobtitle': 'Mechanical Engineer',
#    'latitude': 30.085165,
#    'longitude': -94.0989,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': "<b>Mechanical</b> Specifications Engineer. Maintain and creates the plant's <b>mechanical</b> specifications as it relates to stationary equipment and piping....",
#    'source': 'Burrow Global, LLC',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=526f1c14c33370d7&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'},
#   {'city': 'Houston',
#    'company': 'Arup',
#    'country': 'US',
#    'date': 'Sun, 30 Oct 2016 08:54:21 GMT',
#    'expired': False,
#    'formattedLocation': 'Houston, TX',
#    'formattedLocationFull': 'Houston, TX 77042',
#    'formattedRelativeTime': '19 days ago',
#    'indeedApply': False,
#    'jobkey': 'a2cc583913546a3c',
#    'jobtitle': 'Mechanical Engineer (HVAC)',
#    'latitude': 29.728422,
#    'longitude': -95.556335,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': 'Bachelor’s Degree in <b>Mechanical</b> or Architectural engineering with a sound knowledge of <b>mechanical</b> (HVAC) engineering fundamentals....',
#    'source': 'Arup',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=a2cc583913546a3c&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'},
#   {'city': 'Houston',
#    'company': 'Superior Energy Services, Inc',
#    'country': 'US',
#    'date': 'Tue, 08 Nov 2016 22:28:39 GMT',
#    'expired': False,
#    'formattedLocation': 'Houston, TX',
#    'formattedLocationFull': 'Houston, TX',
#    'formattedRelativeTime': '9 days ago',
#    'indeedApply': False,
#    'jobkey': '8cee7cd5aa4ba526',
#    'jobtitle': 'Design Engineer II',
#    'latitude': 29.760988,
#    'longitude': -95.36264,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': 'Experience with ANSYS <b>Mechanical</b> and Fluent is required 3D modelling skills are required; Knowledge of <b>Mechanical</b> APDL and Fluid-Structural Interaction is...',
#    'source': 'Superior Energy Services, Inc',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=8cee7cd5aa4ba526&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'},
#   {'city': 'Houston',
#    'company': 'AmeriMex Motor & Controls, LLC.',
#    'country': 'US',
#    'date': 'Mon, 14 Nov 2016 18:07:59 GMT',
#    'expired': False,
#    'formattedLocation': 'Houston, TX',
#    'formattedLocationFull': 'Houston, TX',
#    'formattedRelativeTime': '3 days ago',
#    'indeedApply': True,
#    'jobkey': '716062f93d644e9c',
#    'jobtitle': 'Assembly Mechanic',
#    'latitude': 29.760988,
#    'longitude': -95.36264,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': '<b>Mechanical</b> problem-solving ability and troubleshooting skills a must. Must possess two (2) or more year’s general <b>mechanical</b> and/or assembly experience with...',
#    'source': 'Indeed',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=716062f93d644e9c&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'},
#   {'city': 'Humble',
#    'company': 'Marshall Engineering Corporation',
#    'country': 'US',
#    'date': 'Wed, 02 Nov 2016 16:12:35 GMT',
#    'expired': False,
#    'formattedLocation': 'Humble, TX',
#    'formattedLocationFull': 'Humble, TX 77338',
#    'formattedRelativeTime': '16 days ago',
#    'indeedApply': True,
#    'jobkey': '80f95c12bf0c708f',
#    'jobtitle': 'Mechanical Engineer',
#    'latitude': 30.002747,
#    'longitude': -95.27473,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': "<b>Mechanical</b> designers typically review specifications and other data to develop <b>mechanical</b> layouts. <b>Mechanical</b> engineering requires at least a bachelor's degree....",
#    'source': 'Indeed',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=80f95c12bf0c708f&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'},
#   {'city': 'Austin',
#    'company': 'SHEETAK INC.',
#    'country': 'US',
#    'date': 'Tue, 25 Oct 2016 05:33:41 GMT',
#    'expired': False,
#    'formattedLocation': 'Austin, TX',
#    'formattedLocationFull': 'Austin, TX 78744',
#    'formattedRelativeTime': '24 days ago',
#    'indeedApply': True,
#    'jobkey': '6fe33ba4af5de81d',
#    'jobtitle': 'Thermoelectric Product Engineer',
#    'latitude': 30.212498,
#    'longitude': -97.742744,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': 'BS in <b>Mechanical</b> Engineering or Electrical Engineering required; Is commercializing novel solid-state thermoelectric systems for advanced refrigeration,...',
#    'source': 'Indeed',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=6fe33ba4af5de81d&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'},
#   {'city': 'Houston',
#    'company': 'Baker Hughes',
#    'country': 'US',
#    'date': 'Thu, 20 Oct 2016 08:45:56 GMT',
#    'expired': False,
#    'formattedLocation': 'Houston, TX',
#    'formattedLocationFull': 'Houston, TX 77040',
#    'formattedRelativeTime': '29 days ago',
#    'indeedApply': False,
#    'jobkey': 'd6b07becf2eb2bd7',
#    'jobtitle': 'Mechanical Sustaining Engineer - Wellbore Completions - Houston TX',
#    'latitude': 29.892857,
#    'longitude': -95.57692,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': "Bachelor's Degree in <b>Mechanical</b> Engineering with 1+ years <b>mechanical</b> design experience. Knowledge of connections and pipe <b>mechanical</b> properties with experience...",
#    'source': 'Baker Hughes',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=d6b07becf2eb2bd7&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'},
#   {'city': 'College Station',
#    'company': 'Kiewit Corporation',
#    'country': 'US',
#    'date': 'Tue, 15 Nov 2016 20:21:51 GMT',
#    'expired': False,
#    'formattedLocation': 'College Station, TX',
#    'formattedLocationFull': 'College Station, TX',
#    'formattedRelativeTime': '2 days ago',
#    'indeedApply': False,
#    'jobkey': '8342b37713e6b2ee',
#    'jobtitle': 'Mechanical / Maintenance Engineer',
#    'latitude': 30.626373,
#    'longitude': -96.32967,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': 'Undergraduate degree in <b>Mechanical</b> or Industrial Engineering, Diesel/Automotive Technology, Heavy Equipment Technology or relevant discipline....',
#    'source': 'Kiewit Corporation',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=8342b37713e6b2ee&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'},
#   {'city': 'Austin',
#    'company': 'T5 Data Centers',
#    'country': 'US',
#    'date': 'Thu, 10 Nov 2016 21:27:15 GMT',
#    'expired': False,
#    'formattedLocation': 'Austin, TX',
#    'formattedLocationFull': 'Austin, TX',
#    'formattedRelativeTime': '7 days ago',
#    'indeedApply': True,
#    'jobkey': '697230ee9e5784be',
#    'jobtitle': 'Critical Facility Technician (Electrical / Mechanical)',
#    'latitude': 30.266483,
#    'longitude': -97.74176,
#    'onmousedown': "indeed_clk(this,'8974');",
#    'snippet': 'Electrical or <b>mechanical</b> licensure, preferred. Coordinate and oversee janitorial services for raised floor and <b>mechanical</b> / electrical rooms....',
#    'source': 'T5 Data Centers',
#    'sponsored': False,
#    'state': 'TX',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=697230ee9e5784be&qd=1vHU8bY0zJlP3i697aWcB9XxLue5yNridKLsU82kv18BWaJn05Mnjp3U9WeUfRE6LFkfC9qkboCq8iUPnQvfVui0iYTNJc2cuSgLlN87_Wkkt0LCVy_rQinuMfW47e_m&indpubnum=336274463762899&atk=1b1s8fmi0av30fih'}],
#  'start': 1,
#  'totalResults': 3629,
#  'version': 2}

# %%
import pandas as pd 

df = pd.read_json(response_j)
df
# Out:
#    dupefilter  end highlight     location  pageNumber paginationPayload  \
# 0        True   25      True  houston, tx           0
# 1        True   25      True  houston, tx           0
# 2        True   25      True  houston, tx           0
# 3        True   25      True  houston, tx           0
# 4        True   25      True  houston, tx           0
# 5        True   25      True  houston, tx           0
# 6        True   25      True  houston, tx           0
# 7        True   25      True  houston, tx           0
# 8        True   25      True  houston, tx           0
# 9        True   25      True  houston, tx           0
# 10       True   25      True  houston, tx           0
# 11       True   25      True  houston, tx           0
# 12       True   25      True  houston, tx           0
# 13       True   25      True  houston, tx           0
# 14       True   25      True  houston, tx           0
# 15       True   25      True  houston, tx           0
# 16       True   25      True  houston, tx           0
# 17       True   25      True  houston, tx           0
# 18       True   25      True  houston, tx           0
# 19       True   25      True  houston, tx           0
# 20       True   25      True  houston, tx           0
# 21       True   25      True  houston, tx           0
# 22       True   25      True  houston, tx           0
# 23       True   25      True  houston, tx           0
# 24       True   25      True  houston, tx           0
#
#          query  radius                                            results  \
# 0   mechanical     150  {'sponsored': False, 'company': 'Transformer P...
# 1   mechanical     150  {'sponsored': False, 'company': 'Barrios Techn...
# 2   mechanical     150  {'sponsored': False, 'company': 'AmeriMex Moto...
# 3   mechanical     150  {'sponsored': False, 'company': 'ITW', 'indeed...
# 4   mechanical     150  {'sponsored': False, 'company': 'FlowBelow Aer...
# 5   mechanical     150  {'sponsored': False, 'company': 'University of...
# 6   mechanical     150  {'sponsored': False, 'company': 'Weatherford',...
# 7   mechanical     150  {'sponsored': False, 'company': 'Sinopec Tech ...
# 8   mechanical     150  {'sponsored': False, 'company': 'Glumac', 'ind...
# 9   mechanical     150  {'sponsored': False, 'company': 'Hyatt', 'inde...
# 10  mechanical     150  {'sponsored': False, 'company': 'Affiliated En...
# 11  mechanical     150  {'sponsored': False, 'company': 'Applied Mater...
# 12  mechanical     150  {'sponsored': False, 'company': 'Olin Chlor Al...
# 13  mechanical     150  {'sponsored': False, 'company': 'Nabors Indust...
# 14  mechanical     150  {'sponsored': False, 'company': 'Chicago Bridg...
# 15  mechanical     150  {'sponsored': False, 'company': 'SNC-Lavalin',...
# 16  mechanical     150  {'sponsored': False, 'company': 'Burrow Global...
# 17  mechanical     150  {'sponsored': False, 'company': 'Arup', 'indee...
# 18  mechanical     150  {'sponsored': False, 'company': 'Superior Ener...
# 19  mechanical     150  {'sponsored': False, 'company': 'AmeriMex Moto...
# 20  mechanical     150  {'sponsored': False, 'company': 'Marshall Engi...
# 21  mechanical     150  {'sponsored': False, 'company': 'SHEETAK INC.'...
# 22  mechanical     150  {'sponsored': False, 'company': 'Baker Hughes'...
# 23  mechanical     150  {'sponsored': False, 'company': 'Kiewit Corpor...
# 24  mechanical     150  {'sponsored': False, 'company': 'T5 Data Cente...
#
#     start  totalResults  version
# 0       1          3629        2
# 1       1          3629        2
# 2       1          3629        2
# 3       1          3629        2
# 4       1          3629        2
# 5       1          3629        2
# 6       1          3629        2
# 7       1          3629        2
# 8       1          3629        2
# 9       1          3629        2
# 10      1          3629        2
# 11      1          3629        2
# 12      1          3629        2
# 13      1          3629        2
# 14      1          3629        2
# 15      1          3629        2
# 16      1          3629        2
# 17      1          3629        2
# 18      1          3629        2
# 19      1          3629        2
# 20      1          3629        2
# 21      1          3629        2
# 22      1          3629        2
# 23      1          3629        2
# 24      1          3629        2

# %%
df2=df["results"]
df2.to_frame(name=None)
# Out:
#                                               results
# 0   {'sponsored': False, 'company': 'Transformer P...
# 1   {'sponsored': False, 'company': 'Barrios Techn...
# 2   {'sponsored': False, 'company': 'AmeriMex Moto...
# 3   {'sponsored': False, 'company': 'ITW', 'indeed...
# 4   {'sponsored': False, 'company': 'FlowBelow Aer...
# 5   {'sponsored': False, 'company': 'University of...
# 6   {'sponsored': False, 'company': 'Weatherford',...
# 7   {'sponsored': False, 'company': 'Sinopec Tech ...
# 8   {'sponsored': False, 'company': 'Glumac', 'ind...
# 9   {'sponsored': False, 'company': 'Hyatt', 'inde...
# 10  {'sponsored': False, 'company': 'Affiliated En...
# 11  {'sponsored': False, 'company': 'Applied Mater...
# 12  {'sponsored': False, 'company': 'Olin Chlor Al...
# 13  {'sponsored': False, 'company': 'Nabors Indust...
# 14  {'sponsored': False, 'company': 'Chicago Bridg...
# 15  {'sponsored': False, 'company': 'SNC-Lavalin',...
# 16  {'sponsored': False, 'company': 'Burrow Global...
# 17  {'sponsored': False, 'company': 'Arup', 'indee...
# 18  {'sponsored': False, 'company': 'Superior Ener...
# 19  {'sponsored': False, 'company': 'AmeriMex Moto...
# 20  {'sponsored': False, 'company': 'Marshall Engi...
# 21  {'sponsored': False, 'company': 'SHEETAK INC.'...
# 22  {'sponsored': False, 'company': 'Baker Hughes'...
# 23  {'sponsored': False, 'company': 'Kiewit Corpor...
# 24  {'sponsored': False, 'company': 'T5 Data Cente...
