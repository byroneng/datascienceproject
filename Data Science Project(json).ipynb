# %% [markdown]
# # Crawling the Job Market
# Authors: Sameer NANDIKAR(u1010576), Byron ENG <br>
# CS 5963 / MATH 3900 <br>
# email id: sameer.nandikar@gmail.com
#           ; byron.eng@gmail.com

# %% [markdown]
# ## Background and Motivation
# We the authors of this project will be graduating in near future. Thus we need to look for jobs in our respective fields (which in our case is Mechanical Engineering and Atmospheric Sciences) or continue academics in a well-informed direction for better job opportunities. In either case a comperhensive analysis of the job market depicting trends and classifications can be really benificial.
#
# Motivation for this project comes from some obstacles encounterd in the job search, some of which we have tried to elaborate here. Though there are many job search websites which provide a plethora of information about jobs available, one can not draw useful conclusions about the job market such as density of reasearch and development jobs for a mechanical engineer in medical device sector in state of Utah, without analysis of that information. In addition to that, job openings in most of the industries related to Mechanical Engineering are requirement oriented and have very short lead times for joining thus it would be interesting to see if there are any trends in job openings and use the information to benefit the job seekers to decide when to graduate. These are just few queries among other problems we intend to solve.
#
# One more aspect of this project includes classification of jobs according to job function and sector, which will help an aspiring Graduate student to take an informed decision to select an area of interest (such as designing, manufacturing, robotics, energy systems).

# %% [markdown]
# ## Project Objectives
# This project aims to be a tool for anyone entering the job market. The key objective of this project is the analysis of the job market which will include but will not be limited to
# - Geospatial density of jobs
# - Pay rates vs. experience level
# - Pay rates vs. education level
# - Classification of jobs on basis of sector (e.g.aerospace, automobile, medical device, energy, mining equipment etc)
# - Classification of jobs on basis of job function (e.g. production, quality control, design, research and development etc)
# - Annual trend of job openings for different sectors and job functions for different states

# %% [markdown]
# ## Data
#
# At this stage we are looking from which websites we can scrap the data and which websites have APIs. Given below is the information of our current options
#
# ### Inventory of data sources
#
# |Site|Comments|Allowed (scraping)|Disallowed (scraping)|API|API Reference
# |----|--------|:-----:|:--------:|---
# |Glassdoor.com|Has mostly disallows. Because we are going to be using the search, I don't think we are allowed to crawl.||x|Yes|https://www.glassdoor.com/developer/index.htm (access requested)
# |usajobs.gov|Disallows scripts||x|Yes|https://developer.usajobs.gov/API-Reference
# |dice.com|Disallows jobsearch||x|Yes|http://www.dice.com/common/content/util/apidoc/jobsearch.html
# |snagajob.com|Disallows basically everything||x|No|-|
# |simplyhired.com|Links to other sites, disallows job details but not job SEARCH||x|No|-|
# |careerbuilder.com|Disallows everything unless you're the googlebot||x|Yes|Requested key
# |careerinfonet.org|There's a lot that is disallowed, but I don't see anything that is clearly disallowing what we aim to do. Worth another look.||x|No|-|
# |indeed.com|Mostly disallows everything ||x|Yes|Requested key|
# |monster.com|Mostly disallows evferything||x|Yes|Regestration is required for access which is in progress|
# |linkedin.com|Allows scraping with permission||x|Yes|https://api.linkedin.com/v1/people/~?format=json (but an access token is required which is requested)|
# |bls.gov|||x|Yes|http://www.bls.gov/developers/api_python.htm

# %% [markdown]
# ## Data Processing
#
# In addition to APIs, we will keep html scraping as an option. An html of a typical job search website has list of jobs and their links. A dataframe will be created by extracting the information about the jobs from the html page and from nested url links. We will use beautifulsoup and CSS selectors for this purpose. We expect much of the effort to be in data extraction and especially in data clean up because information about the jobs entered may not follow same format most of the times as it is entered by different users. We will be using classification methods to classify the jobs by the desired metrics (ie. degree requirement). Also we need to filter out the features which are out of our present scope of study.

# %% [markdown]
# ## Exploratory Analysis
#
# At this stage we intend to observe trends of job openings geographically as well as annually. Thus we will use scatter plots and other tools we have learned in this class for visualizations. Heuristic approach also seems appropriate for given purposes. For classification we intend to use SVM, Decision trees and k-NN and based on kind of results we get we will select best suitable method.

# %% [markdown]
# ## Analysis Methodlogy
#
# We will first analyze the aggregated data to see geographical and annual trends. Also we will observe the effects of attributes over salary e.g. Pay rates vs. experience level and Pay rates vs. education level.
#
# Secondly for classification purposes based on the size of the data we get from one website we will either divide one website's data into training and test data or use data from one website as training and data from another website as test data. We will use classification methods enlisted above and select the best suitable one to visualize the data in scatter plots

# %% [markdown]
# ## Project Schedule
#
# We have 5 weeks till the presentation date
#
# Week 1 - Data acquisition and cleaning
#
# Week 2 - Data processing
#
# Week 3 and 4 - Exploratory analysis
#
# Week 5 - Preperation for the Presentation

# %% [markdown]
# # Data acquisition and cleaning

# %%
import requests 
import urllib.request
import os.path
city = "salt lake city"
state = "ut"
keyword = "industrial engineering"
url = "http://api.indeed.com/ads/apisearch?publisher=336274463762899&format=json&q="+keyword+"&l="+city+"%2C+"+state+"&sort=&radius=150&st=&jt=fulltime&start=&limit=5000&fromage=&filter=&latlong=1&co=us&chnl=&userip=1.2.3.4&useragent=Mozilla/%2F4.0%28Firefox%29&v=2"
# here it's already a local operation
response = requests.get(url)

response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'{"version":2,"query":"industrial engineering","location":"salt lake city, ut","paginationPayload":"","radius":150,"dupefilter":true,"highlight":true,"totalResults":200,"start":1,"end":25,"pageNumber":0,"results":[{"jobtitle":"Industrial Engineer","company":"XPO Logistics","city":"West Valley City","state":"UT","country":"US","formattedLocation":"West Valley City, UT","source":"XPO Logistics, Inc.","date":"Wed, 23 Nov 2016 00:08:13 GMT","snippet":"BA/BS degree in <b>Engineering</b> or related field. Support plant operations as directed by <b>Engineering</b> Manager; Extensive experience in quality, <b>engineering</b>, lean...","url":"http://www.indeed.com/viewjob?jk=b116e31f90d31f00&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj","onmousedown":"indeed_clk(this,\'9602\');","latitude":40.695053,"longitude":-112.01649,"jobkey":"b116e31f90d31f00","sponsored":false,"expired":false,"indeedApply":false,"formattedLocationFull":"West Valley City, UT 84120","formattedRelativeTime":"3 days ago","stations":""},{"jobtitle":"Maintenance Technician/Planner","company":"Hoyt Archery","city":"Salt Lake City","state":"UT","country":"US","formattedLocation":"Salt Lake City, UT","source":"Indeed","date":"Mon, 21 Nov 2016 20:31:51 GMT","snippet":"Skill in electrical, <b>industrial</b> wiring; Read and understand <b>engineering</b> prints and schematics; Hoyt Archery Company, a premier manufacturer of archery products,...","url":"http://www.indeed.com/viewjob?jk=95f00f008878c12d&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj","onmousedown":"indeed_clk(this,\'9602\');","latitude":40.758244,"longitude":-111.89011,"jobkey":"95f00f008878c12d","sponsored":false,"expired":false,"indeedApply":true,"formattedLocationFull":"Salt Lake City, UT","formattedRelativeTime":"4 days ago","stations":""},{"jobtitle":"Plant Operations/Maintenance Planner","company":"Pacificorp","city":"Kemmerer","state":"WY","country":"US","formattedLocation":"Kemmerer, WY","source":"Pacificorp","date":"Thu, 17 Nov 2016 00:18:52 GMT","snippet":"Ability to supervise union personnel in an <b>industrial</b> environment. Previous experience as a maintenance supervisor at an <b>industrial</b> facility or power plant....","url":"http://www.indeed.com/viewjob?jk=e34409cfe22ac5d6&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj","onmousedown":"indeed_clk(this,\'9602\');","latitude":41.79121,"longitude":-110.53297,"jobkey":"e34409cfe22ac5d6","sponsored":false,"expired":false,"indeedApply":false,"formattedLocationFull":"Kemmerer, WY","formattedRelativeTime":"9 days ago","stations":""},{"jobtitle":"Early Career Program - Integrated Supply Chain","company":"Hexcel Corporation","city":"Salt Lake City","state":"UT","country":"US","formattedLocation":"Salt Lake City, UT","source":"Hexcel Corporation","date":"Mon, 12 Sep 2016 16:40:06 GMT","snippet":"Preferred degrees are Chemical <b>Engineering</b>, Mechanical <b>Engineering</b> or Materials Science and <b>Engineering</b>. Being a member of Integrated Supply Chain team will...","url":"http://www.indeed.com/viewjob?jk=b2b08fa2421d4f66&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj","onmousedown":"indeed_clk(this,\'9602\');","latitude":40.758244,"longitude":-111.89011,"jobkey":"b2b08fa2421d4f66","sponsored":false,"expired":false,"indeedApply":false,"formattedLocationFull":"Salt Lake City, UT","formattedRelativeTime":"30+ days ago","stations":""},{"j ...

# %%
response_j = response.content.decode("utf-8")
print(response_j)
# Out:
# {"version":2,"query":"industrial engineering","location":"salt lake city, ut","paginationPayload":"","radius":150,"dupefilter":true,"highlight":true,"totalResults":200,"start":1,"end":25,"pageNumber":0,"results":[{"jobtitle":"Industrial Engineer","company":"XPO Logistics","city":"West Valley City","state":"UT","country":"US","formattedLocation":"West Valley City, UT","source":"XPO Logistics, Inc.","date":"Wed, 23 Nov 2016 00:08:13 GMT","snippet":"BA/BS degree in <b>Engineering</b> or related field. Support plant operations as directed by <b>Engineering</b> Manager; Extensive experience in quality, <b>engineering</b>, lean...","url":"http://www.indeed.com/viewjob?jk=b116e31f90d31f00&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj","onmousedown":"indeed_clk(this,'9602');","latitude":40.695053,"longitude":-112.01649,"jobkey":"b116e31f90d31f00","sponsored":false,"expired":false,"indeedApply":false,"formattedLocationFull":"West Valley City, UT 84120","formattedRelativeTime":"3 days ago","stations":""},{"jobtitle":"Maintenance Technician/Planner","company":"Hoyt Archery","city":"Salt Lake City","state":"UT","country":"US","formattedLocation":"Salt Lake City, UT","source":"Indeed","date":"Mon, 21 Nov 2016 20:31:51 GMT","snippet":"Skill in electrical, <b>industrial</b> wiring; Read and understand <b>engineering</b> prints and schematics; Hoyt Archery Company, a premier manufacturer of archery products,...","url":"http://www.indeed.com/viewjob?jk=95f00f008878c12d&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj","onmousedown":"indeed_clk(this,'9602');","latitude":40.758244,"longitude":-111.89011,"jobkey":"95f00f008878c12d","sponsored":false,"expired":false,"indeedApply":true,"formattedLocationFull":"Salt Lake City, UT","formattedRelativeTime":"4 days ago","stations":""},{"jobtitle":"Plant Operations/Maintenance Planner","company":"Pacificorp","city":"Kemmerer","state":"WY","country":"US","formattedLocation":"Kemmerer, WY","source":"Pacificorp","date":"Thu, 17 Nov 2016 00:18:52 GMT","snippet":"Ability to supervise union personnel in an <b>industrial</b> environment. Previous experience as a maintenance supervisor at an <b>industrial</b> facility or power plant....","url":"http://www.indeed.com/viewjob?jk=e34409cfe22ac5d6&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj","onmousedown":"indeed_clk(this,'9602');","latitude":41.79121,"longitude":-110.53297,"jobkey":"e34409cfe22ac5d6","sponsored":false,"expired":false,"indeedApply":false,"formattedLocationFull":"Kemmerer, WY","formattedRelativeTime":"9 days ago","stations":""},{"jobtitle":"Early Career Program - Integrated Supply Chain","company":"Hexcel Corporation","city":"Salt Lake City","state":"UT","country":"US","formattedLocation":"Salt Lake City, UT","source":"Hexcel Corporation","date":"Mon, 12 Sep 2016 16:40:06 GMT","snippet":"Preferred degrees are Chemical <b>Engineering</b>, Mechanical <b>Engineering</b> or Materials Science and <b>Engineering</b>. Being a member of Integrated Supply Chain team will...","url":"http://www.indeed.com/viewjob?jk=b2b08fa2421d4f66&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj","onmousedown":"indeed_clk(this,'9602');","latitude":40.758244,"longitude":-111.89011,"jobkey":"b2b08fa2421d4f66","sponsored":false,"expired":false,"indeedApply":false,"formattedLocationFull":"Salt Lake City, UT","formattedRelativeTime":"30+ days ago","stations":""},{"jobtitle":" ...

# %%
import json
response_d = json.loads(response_j)
print(type(response_d))
response_d
# Out:
# <class 'dict'>
# {'dupefilter': True,
#  'end': 25,
#  'highlight': True,
#  'location': 'salt lake city, ut',
#  'pageNumber': 0,
#  'paginationPayload': '',
#  'query': 'industrial engineering',
#  'radius': 150,
#  'results': [{'city': 'West Valley City',
#    'company': 'XPO Logistics',
#    'country': 'US',
#    'date': 'Wed, 23 Nov 2016 00:08:13 GMT',
#    'expired': False,
#    'formattedLocation': 'West Valley City, UT',
#    'formattedLocationFull': 'West Valley City, UT 84120',
#    'formattedRelativeTime': '3 days ago',
#    'indeedApply': False,
#    'jobkey': 'b116e31f90d31f00',
#    'jobtitle': 'Industrial Engineer',
#    'latitude': 40.695053,
#    'longitude': -112.01649,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': 'BA/BS degree in <b>Engineering</b> or related field. Support plant operations as directed by <b>Engineering</b> Manager; Extensive experience in quality, <b>engineering</b>, lean...',
#    'source': 'XPO Logistics, Inc.',
#    'sponsored': False,
#    'state': 'UT',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=b116e31f90d31f00&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'},
#   {'city': 'Salt Lake City',
#    'company': 'Hoyt Archery',
#    'country': 'US',
#    'date': 'Mon, 21 Nov 2016 20:31:51 GMT',
#    'expired': False,
#    'formattedLocation': 'Salt Lake City, UT',
#    'formattedLocationFull': 'Salt Lake City, UT',
#    'formattedRelativeTime': '4 days ago',
#    'indeedApply': True,
#    'jobkey': '95f00f008878c12d',
#    'jobtitle': 'Maintenance Technician/Planner',
#    'latitude': 40.758244,
#    'longitude': -111.89011,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': 'Skill in electrical, <b>industrial</b> wiring; Read and understand <b>engineering</b> prints and schematics; Hoyt Archery Company, a premier manufacturer of archery products,...',
#    'source': 'Indeed',
#    'sponsored': False,
#    'state': 'UT',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=95f00f008878c12d&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'},
#   {'city': 'Kemmerer',
#    'company': 'Pacificorp',
#    'country': 'US',
#    'date': 'Thu, 17 Nov 2016 00:18:52 GMT',
#    'expired': False,
#    'formattedLocation': 'Kemmerer, WY',
#    'formattedLocationFull': 'Kemmerer, WY',
#    'formattedRelativeTime': '9 days ago',
#    'indeedApply': False,
#    'jobkey': 'e34409cfe22ac5d6',
#    'jobtitle': 'Plant Operations/Maintenance Planner',
#    'latitude': 41.79121,
#    'longitude': -110.53297,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': 'Ability to supervise union personnel in an <b>industrial</b> environment. Previous experience as a maintenance supervisor at an <b>industrial</b> facility or power plant....',
#    'source': 'Pacificorp',
#    'sponsored': False,
#    'state': 'WY',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=e34409cfe22ac5d6&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'},
#   {'city': 'Salt Lake City',
#    'company': 'Hexcel Corporation',
#    'country': 'US',
#    'date': 'Mon, 12 Sep 2016 16:40:06 GMT',
#    'expired': False,
#    'formattedLocation': 'Salt Lake City, UT',
#    'formattedLocationFull': 'Salt Lake City, UT',
#    'formattedRelativeTime': '30+ days ago',
#    'indeedApply': False,
#    'jobkey': 'b2b08fa2421d4f66',
#    'jobtitle': 'Early Career Program - Integrated Supply Chain',
#    'latitude': 40.758244,
#    'longitude': -111.89011,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': 'Preferred degrees are Chemical <b>Engineering</b>, Mechanical <b>Engineering</b> or Materials Science and <b>Engineering</b>. Being a member of Integrated Supply Chain team will...',
#    'source': 'Hexcel Corporation',
#    'sponsored': False,
#    'state': 'UT',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=b2b08fa2421d4f66&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'},
#   {'city': 'Salt Lake City',
#    'company': 'NobleTek',
#    'country': 'US',
#    'date': 'Fri, 11 Nov 2016 14:24:44 GMT',
#    'expired': False,
#    'formattedLocation': 'Salt Lake City, UT',
#    'formattedLocationFull': 'Salt Lake City, UT',
#    'formattedRelativeTime': '15 days ago',
#    'indeedApply': True,
#    'jobkey': '347194119099c79f',
#    'jobtitle': 'PLM Implementation Specialist Teamcenter',
#    'latitude': 40.758244,
#    'longitude': -111.89011,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': 'Familiar with <b>engineering</b> and manufacturing domains. Bachelor’s degree in <b>Engineering</b>, Computer Science, or similar technical degree is required....',
#    'source': 'Indeed',
#    'sponsored': False,
#    'state': 'UT',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=347194119099c79f&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'},
#   {'city': 'Salt Lake City',
#    'company': 'The Grange LLC',
#    'country': 'US',
#    'date': 'Mon, 14 Nov 2016 03:58:23 GMT',
#    'expired': False,
#    'formattedLocation': 'Salt Lake City, UT',
#    'formattedLocationFull': 'Salt Lake City, UT 84111',
#    'formattedRelativeTime': '12 days ago',
#    'indeedApply': True,
#    'jobkey': 'd15a1e7c6ddf4a37',
#    'jobtitle': 'Plant Manager',
#    'latitude': 40.752747,
#    'longitude': -111.87912,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': 'Bachelor’s degree in <b>Industrial</b> <b>Engineering</b>, Operations Management, Business Administration or equivalent. Is looking for an experienced *Plant Manager*....',
#    'source': 'Indeed',
#    'sponsored': False,
#    'state': 'UT',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=d15a1e7c6ddf4a37&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'},
#   {'city': 'Salt Lake City',
#    'company': 'Leidos',
#    'country': 'US',
#    'date': 'Tue, 04 Oct 2016 04:18:20 GMT',
#    'expired': False,
#    'formattedLocation': 'Salt Lake City, UT',
#    'formattedLocationFull': 'Salt Lake City, UT 84102',
#    'formattedRelativeTime': '30+ days ago',
#    'indeedApply': False,
#    'jobkey': 'a3a2d67c96aa3d4c',
#    'jobtitle': 'Special Security Officer',
#    'latitude': 40.758244,
#    'longitude': -111.86264,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': '- <b>Industrial</b>, physical, personnel (JPAS) security experience. Government civil agencies and commercial health and <b>engineering</b> markets....',
#    'source': 'Leidos',
#    'sponsored': False,
#    'state': 'UT',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=a3a2d67c96aa3d4c&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'},
#   {'city': 'Salt Lake City',
#    'company': 'US Tool Group',
#    'country': 'US',
#    'date': 'Fri, 26 Aug 2016 17:04:25 GMT',
#    'expired': False,
#    'formattedLocation': 'Salt Lake City, UT',
#    'formattedLocationFull': 'Salt Lake City, UT',
#    'formattedRelativeTime': '30+ days ago',
#    'indeedApply': False,
#    'jobkey': '797da9e5532856a7',
#    'jobtitle': 'Material Handler',
#    'latitude': 40.758244,
#    'longitude': -111.89011,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': 'Integrated Supply Chain Management, Production Cutting Tool Reconditioning, <b>Industrial</b> Vending, Value Added Solutions, Information Technology and Product...',
#    'source': 'US Tool Group',
#    'sponsored': False,
#    'state': 'UT',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=797da9e5532856a7&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'},
#   {'city': 'Orem',
#    'company': 'Utah Valley University',
#    'country': 'US',
#    'date': 'Wed, 23 Nov 2016 21:39:59 GMT',
#    'expired': False,
#    'formattedLocation': 'Orem, UT',
#    'formattedLocationFull': 'Orem, UT 84058',
#    'formattedRelativeTime': '2 days ago',
#    'indeedApply': False,
#    'jobkey': '8236907c8fca09b3',
#    'jobtitle': 'Lab Manager II - Engineering Technology',
#    'latitude': 40.28022,
#    'longitude': -111.6978,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': 'Electrical <b>Engineering</b>, Mechanical <b>Engineering</b>, Mechatronics, <b>Engineering</b> Technology, Automation, or Manufacturing....',
#    'source': 'Utah Valley University',
#    'sponsored': False,
#    'state': 'UT',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=8236907c8fca09b3&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'},
#   {'city': 'Salt Lake City',
#    'company': 'McKinstry',
#    'country': 'US',
#    'date': 'Thu, 03 Nov 2016 03:53:55 GMT',
#    'expired': False,
#    'formattedLocation': 'Salt Lake City, UT',
#    'formattedLocationFull': 'Salt Lake City, UT',
#    'formattedRelativeTime': '23 days ago',
#    'indeedApply': False,
#    'jobkey': 'b8510ad9a74a2bd4',
#    'jobtitle': 'Mission Critical Engineering Specialist',
#    'latitude': 40.758244,
#    'longitude': -111.89011,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': 'Development of Customer Mission Critical <b>Engineering</b> standards. Degree in Systems <b>Engineering</b> or equivalent professional experience preferred....',
#    'source': 'McKinstry',
#    'sponsored': False,
#    'state': 'UT',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=b8510ad9a74a2bd4&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'},
#   {'city': 'Salt Lake City',
#    'company': 'Hexcel Corporation',
#    'country': 'US',
#    'date': 'Wed, 28 Sep 2016 17:23:40 GMT',
#    'expired': False,
#    'formattedLocation': 'Salt Lake City, UT',
#    'formattedLocationFull': 'Salt Lake City, UT',
#    'formattedRelativeTime': '30+ days ago',
#    'indeedApply': False,
#    'jobkey': '9faabb9d22af27ed',
#    'jobtitle': 'Customer Service Representative',
#    'latitude': 40.758244,
#    'longitude': -111.89011,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': 'With our strong investment in research and development, and culture of continuous improvement, Hexcel is the industry leader in the manufacturing of <b>industrial</b>...',
#    'source': 'Hexcel Corporation',
#    'sponsored': False,
#    'state': 'UT',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=9faabb9d22af27ed&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'},
#   {'city': 'Salt Lake City',
#    'company': 'L-3 Communications',
#    'country': 'US',
#    'date': 'Thu, 24 Nov 2016 09:04:16 GMT',
#    'expired': False,
#    'formattedLocation': 'Salt Lake City, UT',
#    'formattedLocationFull': 'Salt Lake City, UT 84116',
#    'formattedRelativeTime': '2 days ago',
#    'indeedApply': False,
#    'jobkey': '72e3fd2360e7173c',
#    'jobtitle': 'Industrial Engineering Technician',
#    'latitude': 40.783127,
#    'longitude': -111.951614,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': 'The Industrial Engineering Technician will be responsible for keeping production flowing, for meeting production performance goals, and for maintaining...',
#    'source': 'L-3 Communications',
#    'sponsored': False,
#    'state': 'UT',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=72e3fd2360e7173c&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'},
#   {'city': 'Salt Lake',
#    'company': 'USG/Westech Services, INC',
#    'country': 'US',
#    'date': 'Tue, 08 Nov 2016 13:49:30 GMT',
#    'expired': False,
#    'formattedLocation': 'Salt Lake, UT',
#    'formattedLocationFull': 'Salt Lake, UT',
#    'formattedRelativeTime': '18 days ago',
#    'indeedApply': True,
#    'jobkey': '6e3fd95a2a9283d2',
#    'jobtitle': 'Electro-Mechanical Field Service Technician',
#    'latitude': 40.906593,
#    'longitude': -111.86264,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': 'Heavy-duty, non-IT <b>industrial</b> machinery repair:. For individuals who may be seeking supervisory, <b>engineering</b> or management positions....',
#    'source': 'Indeed',
#    'sponsored': False,
#    'state': 'UT',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=6e3fd95a2a9283d2&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'},
#   {'city': 'Ogden',
#    'company': 'Autoliv',
#    'country': 'US',
#    'date': 'Mon, 21 Nov 2016 14:12:05 GMT',
#    'expired': False,
#    'formattedLocation': 'Ogden, UT',
#    'formattedLocationFull': 'Ogden, UT 84401',
#    'formattedRelativeTime': '5 days ago',
#    'indeedApply': True,
#    'jobkey': '831e36571b34841d',
#    'jobtitle': 'Industrial Engineeer',
#    'latitude': 41.2052,
#    'longitude': -112.0036,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': 'Prior experience in process or <b>industrial</b> <b>engineering</b> and project management are preferred. Bachelor of Science in <b>Engineering</b> is required....',
#    'source': 'Indeed',
#    'sponsored': False,
#    'state': 'UT',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=831e36571b34841d&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'},
#   {'city': 'Salt Lake City',
#    'company': 'KURU Footwear',
#    'country': 'US',
#    'date': 'Mon, 31 Oct 2016 18:00:11 GMT',
#    'expired': False,
#    'formattedLocation': 'Salt Lake City, UT',
#    'formattedLocationFull': 'Salt Lake City, UT 84123',
#    'formattedRelativeTime': '26 days ago',
#    'indeedApply': True,
#    'jobkey': '2de53dc066cd2257',
#    'jobtitle': 'Footwear Product Development Assistant',
#    'latitude': 40.656593,
#    'longitude': -111.92308,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': 'Bachelors Degree in <b>Industrial</b> Design, <b>Engineering</b> and/or Equivalent degree experience. KURU Footwear is a direct to consumer footwear brand that is growing and...',
#    'source': 'Indeed',
#    'sponsored': False,
#    'state': 'UT',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=2de53dc066cd2257&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'},
#   {'city': 'Bacchus',
#    'company': 'Orbital ATK',
#    'country': 'US',
#    'date': 'Wed, 09 Nov 2016 00:17:46 GMT',
#    'expired': False,
#    'formattedLocation': 'Bacchus, UT',
#    'formattedLocationFull': 'Bacchus, UT',
#    'formattedRelativeTime': '17 days ago',
#    'indeedApply': False,
#    'jobkey': '288d3b04217275c0',
#    'jobtitle': 'Industrial Hygiene Summer Internship',
#    'latitude': 40.662086,
#    'longitude': -112.09341,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': '<b>Industrial</b> Hygiene Summer Internship. <b>Industrial</b> Hygiene or related field. Safety and <b>Industrial</b> Hygiene Internship at Utah’s Bacchus and Promontory Facilities....',
#    'source': 'Orbital ATK',
#    'sponsored': False,
#    'state': 'UT',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=288d3b04217275c0&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'},
#   {'city': 'Salt Lake City',
#    'company': 'University of Utah',
#    'country': 'US',
#    'date': 'Wed, 12 Oct 2016 16:10:20 GMT',
#    'expired': False,
#    'formattedLocation': 'Salt Lake City, UT',
#    'formattedLocationFull': 'Salt Lake City, UT',
#    'formattedRelativeTime': '30+ days ago',
#    'indeedApply': False,
#    'jobkey': 'ad09f6790c0d8d36',
#    'jobtitle': 'Sr Industrial Hygienist',
#    'latitude': 40.758244,
#    'longitude': -111.89011,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': 'Five years experience in <b>Industrial</b> Hygiene; Supervisory responsibilities for a team of occupational safety specialists and <b>industrial</b> hygienists....',
#    'source': 'University of Utah',
#    'sponsored': False,
#    'state': 'UT',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=ad09f6790c0d8d36&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'},
#   {'city': 'Midvale',
#    'company': 'Savage',
#    'country': 'US',
#    'date': 'Thu, 24 Nov 2016 03:02:21 GMT',
#    'expired': False,
#    'formattedLocation': 'Midvale, UT',
#    'formattedLocationFull': 'Midvale, UT',
#    'formattedRelativeTime': '2 days ago',
#    'indeedApply': False,
#    'jobkey': '94c0f761d8380171',
#    'jobtitle': 'Senior Project Manager - Engineering',
#    'latitude': 40.60989,
#    'longitude': -111.89561,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': 'BS/BA <b>Engineering</b>, Construction Management or equivalent work experience required. We are the leading provider of fully integrated systems, designed and...',
#    'source': 'Savage',
#    'sponsored': False,
#    'state': 'UT',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=94c0f761d8380171&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'},
#   {'city': 'Salt Lake City',
#    'company': 'MYR Group Inc.',
#    'country': 'US',
#    'date': 'Wed, 23 Nov 2016 23:34:31 GMT',
#    'expired': False,
#    'formattedLocation': 'Salt Lake City, UT',
#    'formattedLocationFull': 'Salt Lake City, UT',
#    'formattedRelativeTime': '2 days ago',
#    'indeedApply': False,
#    'jobkey': '8d4f6d7b23fbd159',
#    'jobtitle': 'Estimator C & I',
#    'latitude': 40.758244,
#    'longitude': -111.89011,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': 'Degree in Electrical <b>Engineering</b>, Construction or related field desirable but not essential. Preparation of complete cost estimates (labor and material) for...',
#    'source': 'MYR Group Inc.',
#    'sponsored': False,
#    'state': 'UT',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=8d4f6d7b23fbd159&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'},
#   {'city': 'Pocatello',
#    'company': 'ON Semiconductor',
#    'country': 'US',
#    'date': 'Wed, 09 Nov 2016 23:04:02 GMT',
#    'expired': False,
#    'formattedLocation': 'Pocatello, ID',
#    'formattedLocationFull': 'Pocatello, ID',
#    'formattedRelativeTime': '16 days ago',
#    'indeedApply': False,
#    'jobkey': '7f4482c08399d3b3',
#    'jobtitle': 'Product Engineering Technician',
#    'latitude': 42.87088,
#    'longitude': -112.44505,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': 'Higher, preferably in the Electrical <b>Engineering</b> field. Use of available lab....',
#    'source': 'ON Semiconductor',
#    'sponsored': False,
#    'state': 'ID',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=7f4482c08399d3b3&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'},
#   {'city': 'Ogden',
#    'company': 'PrincePerelson',
#    'country': 'US',
#    'date': 'Thu, 17 Nov 2016 18:19:53 GMT',
#    'expired': False,
#    'formattedLocation': 'Ogden, UT',
#    'formattedLocationFull': 'Ogden, UT',
#    'formattedRelativeTime': '8 days ago',
#    'indeedApply': True,
#    'jobkey': '6d925307f34396f0',
#    'jobtitle': 'Manufacturing Engineer',
#    'latitude': 41.222527,
#    'longitude': -111.97253,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': "Bachelor's degree in <b>Industrial</b> or Manufacturing <b>Engineering</b>. Solid understand of mechanical and electrical components of heavy <b>industrial</b> equipment....",
#    'source': 'Indeed',
#    'sponsored': False,
#    'state': 'UT',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=6d925307f34396f0&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'},
#   {'city': 'Salt Lake City',
#    'company': 'Synerlink',
#    'country': 'US',
#    'date': 'Wed, 26 Oct 2016 03:49:54 GMT',
#    'expired': False,
#    'formattedLocation': 'Salt Lake City, UT',
#    'formattedLocationFull': 'Salt Lake City, UT',
#    'formattedRelativeTime': '30+ days ago',
#    'indeedApply': True,
#    'jobkey': '41e52b48aee88cd9',
#    'jobtitle': 'Field Service Automation Specialist',
#    'latitude': 40.758244,
#    'longitude': -111.89011,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': 'Synerlink uses proprietary <b>industrial</b> automation software applications. Barry-Wehmiller is a leading supplier of <b>engineering</b> consulting and manufacturing...',
#    'source': 'Barry Wehmiller Companies Inc',
#    'sponsored': False,
#    'state': 'UT',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=41e52b48aee88cd9&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'},
#   {'city': 'Salt Lake City',
#    'company': 'Albany International Corp.',
#    'country': 'US',
#    'date': 'Mon, 14 Nov 2016 22:52:40 GMT',
#    'expired': False,
#    'formattedLocation': 'Salt Lake City, UT',
#    'formattedLocationFull': 'Salt Lake City, UT 84116',
#    'formattedRelativeTime': '11 days ago',
#    'indeedApply': False,
#    'jobkey': '7ac24eff02ceef1e',
#    'jobtitle': 'ESH Specialist III',
#    'latitude': 40.782967,
#    'longitude': -111.92857,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': "Bachelor's degree in Environmental <b>Engineering</b>, Safety <b>Engineering</b>, or a related field. Five (5) years <b>industrial</b> manufacturing experience, including but not...",
#    'source': 'Albany International Corp.',
#    'sponsored': False,
#    'state': 'UT',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=7ac24eff02ceef1e&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'},
#   {'city': 'Salt Lake City',
#    'company': 'Wynright Corporation',
#    'country': 'US',
#    'date': 'Thu, 13 Oct 2016 01:19:41 GMT',
#    'expired': False,
#    'formattedLocation': 'Salt Lake City, UT',
#    'formattedLocationFull': 'Salt Lake City, UT',
#    'formattedRelativeTime': '30+ days ago',
#    'indeedApply': False,
#    'jobkey': '46ece1df9db79915',
#    'jobtitle': 'Senior Project Engineer',
#    'latitude': 40.758244,
#    'longitude': -111.89011,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': 'Creates <b>engineering</b> designs for <b>industrial</b> material handling storage systems. Minimum of 5 years of experience in <b>engineering</b> design and project execution....',
#    'source': 'Wynright Corporation',
#    'sponsored': False,
#    'state': 'UT',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=46ece1df9db79915&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'},
#   {'city': 'Salt Lake City',
#    'company': 'AECOM',
#    'country': 'US',
#    'date': 'Tue, 25 Oct 2016 00:56:41 GMT',
#    'expired': False,
#    'formattedLocation': 'Salt Lake City, UT',
#    'formattedLocationFull': 'Salt Lake City, UT',
#    'formattedRelativeTime': '30+ days ago',
#    'indeedApply': False,
#    'jobkey': '5a4fc35592ec97d1',
#    'jobtitle': 'Water Resources Engineering Department Intern',
#    'latitude': 40.758244,
#    'longitude': -111.89011,
#    'onmousedown': "indeed_clk(this,'9602');",
#    'snippet': 'Willingness to work in multiple <b>engineering</b> and <b>engineering</b> related disciplines. The Salt Lake City AECOM office is staffed by over 100 science and <b>engineering</b>...',
#    'source': 'AECOM',
#    'sponsored': False,
#    'state': 'UT',
#    'stations': '',
#    'url': 'http://www.indeed.com/viewjob?jk=5a4fc35592ec97d1&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'}],
#  'start': 1,
#  'totalResults': 200,
#  'version': 2}

# %%
import pandas as pd 

df = pd.read_json(response_j)
df
# Out:
#    dupefilter  end highlight            location  pageNumber  \
# 0        True   25      True  salt lake city, ut           0
# 1        True   25      True  salt lake city, ut           0
# 2        True   25      True  salt lake city, ut           0
# 3        True   25      True  salt lake city, ut           0
# 4        True   25      True  salt lake city, ut           0
# 5        True   25      True  salt lake city, ut           0
# 6        True   25      True  salt lake city, ut           0
# 7        True   25      True  salt lake city, ut           0
# 8        True   25      True  salt lake city, ut           0
# 9        True   25      True  salt lake city, ut           0
# 10       True   25      True  salt lake city, ut           0
# 11       True   25      True  salt lake city, ut           0
# 12       True   25      True  salt lake city, ut           0
# 13       True   25      True  salt lake city, ut           0
# 14       True   25      True  salt lake city, ut           0
# 15       True   25      True  salt lake city, ut           0
# 16       True   25      True  salt lake city, ut           0
# 17       True   25      True  salt lake city, ut           0
# 18       True   25      True  salt lake city, ut           0
# 19       True   25      True  salt lake city, ut           0
# 20       True   25      True  salt lake city, ut           0
# 21       True   25      True  salt lake city, ut           0
# 22       True   25      True  salt lake city, ut           0
# 23       True   25      True  salt lake city, ut           0
# 24       True   25      True  salt lake city, ut           0
#
#    paginationPayload                   query  radius  \
# 0                     industrial engineering     150
# 1                     industrial engineering     150
# 2                     industrial engineering     150
# 3                     industrial engineering     150
# 4                     industrial engineering     150
# 5                     industrial engineering     150
# 6                     industrial engineering     150
# 7                     industrial engineering     150
# 8                     industrial engineering     150
# 9                     industrial engineering     150
# 10                    industrial engineering     150
# 11                    industrial engineering     150
# 12                    industrial engineering     150
# 13                    industrial engineering     150
# 14                    industrial engineering     150
# 15                    industrial engineering     150
# 16                    industrial engineering     150
# 17                    industrial engineering     150
# 18                    industrial engineering     150
# 19                    industrial engineering     150
# 20                    industrial engineering     150
# 21                    industrial engineering     150
# 22                    industrial engineering     150
# 23                    industrial engineering     150
# 24                    industrial engineering     150
#
#                                               results  start  totalResults  \
# 0   {'country': 'US', 'city': 'West Valley City', ...      1           200
# 1   {'country': 'US', 'city': 'Salt Lake City', 's...      1           200
# 2   {'country': 'US', 'city': 'Kemmerer', 'snippet...      1           200
# 3   {'country': 'US', 'city': 'Salt Lake City', 's...      1           200
# 4   {'country': 'US', 'city': 'Salt Lake City', 's...      1           200
# 5   {'country': 'US', 'city': 'Salt Lake City', 's...      1           200
# 6   {'country': 'US', 'city': 'Salt Lake City', 's...      1           200
# 7   {'country': 'US', 'city': 'Salt Lake City', 's...      1           200
# 8   {'country': 'US', 'city': 'Orem', 'snippet': '...      1           200
# 9   {'country': 'US', 'city': 'Salt Lake City', 's...      1           200
# 10  {'country': 'US', 'city': 'Salt Lake City', 's...      1           200
# 11  {'country': 'US', 'city': 'Salt Lake City', 's...      1           200
# 12  {'country': 'US', 'city': 'Salt Lake', 'snippe...      1           200
# 13  {'country': 'US', 'city': 'Ogden', 'snippet': ...      1           200
# 14  {'country': 'US', 'city': 'Salt Lake City', 's...      1           200
# 15  {'country': 'US', 'city': 'Bacchus', 'snippet'...      1           200
# 16  {'country': 'US', 'city': 'Salt Lake City', 's...      1           200
# 17  {'country': 'US', 'city': 'Midvale', 'snippet'...      1           200
# 18  {'country': 'US', 'city': 'Salt Lake City', 's...      1           200
# 19  {'country': 'US', 'city': 'Pocatello', 'snippe...      1           200
# 20  {'country': 'US', 'city': 'Ogden', 'snippet': ...      1           200
# 21  {'country': 'US', 'city': 'Salt Lake City', 's...      1           200
# 22  {'country': 'US', 'city': 'Salt Lake City', 's...      1           200
# 23  {'country': 'US', 'city': 'Salt Lake City', 's...      1           200
# 24  {'country': 'US', 'city': 'Salt Lake City', 's...      1           200
#
#     version
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2
# 5         2
# 6         2
# 7         2
# 8         2
# 9         2
# 10        2
# 11        2
# 12        2
# 13        2
# 14        2
# 15        2
# 16        2
# 17        2
# 18        2
# 19        2
# 20        2
# 21        2
# 22        2
# 23        2
# 24        2

# %%
df2=df["results"]
df2.to_frame(name=None)
# Out:
#                                               results
# 0   {'country': 'US', 'city': 'West Valley City', ...
# 1   {'country': 'US', 'city': 'Salt Lake City', 's...
# 2   {'country': 'US', 'city': 'Kemmerer', 'snippet...
# 3   {'country': 'US', 'city': 'Salt Lake City', 's...
# 4   {'country': 'US', 'city': 'Salt Lake City', 's...
# 5   {'country': 'US', 'city': 'Salt Lake City', 's...
# 6   {'country': 'US', 'city': 'Salt Lake City', 's...
# 7   {'country': 'US', 'city': 'Salt Lake City', 's...
# 8   {'country': 'US', 'city': 'Orem', 'snippet': '...
# 9   {'country': 'US', 'city': 'Salt Lake City', 's...
# 10  {'country': 'US', 'city': 'Salt Lake City', 's...
# 11  {'country': 'US', 'city': 'Salt Lake City', 's...
# 12  {'country': 'US', 'city': 'Salt Lake', 'snippe...
# 13  {'country': 'US', 'city': 'Ogden', 'snippet': ...
# 14  {'country': 'US', 'city': 'Salt Lake City', 's...
# 15  {'country': 'US', 'city': 'Bacchus', 'snippet'...
# 16  {'country': 'US', 'city': 'Salt Lake City', 's...
# 17  {'country': 'US', 'city': 'Midvale', 'snippet'...
# 18  {'country': 'US', 'city': 'Salt Lake City', 's...
# 19  {'country': 'US', 'city': 'Pocatello', 'snippe...
# 20  {'country': 'US', 'city': 'Ogden', 'snippet': ...
# 21  {'country': 'US', 'city': 'Salt Lake City', 's...
# 22  {'country': 'US', 'city': 'Salt Lake City', 's...
# 23  {'country': 'US', 'city': 'Salt Lake City', 's...
# 24  {'country': 'US', 'city': 'Salt Lake City', 's...

# %%
    df.get_value(1,'results')
# Out:
# {'city': 'Salt Lake City',
#  'company': 'Hoyt Archery',
#  'country': 'US',
#  'date': 'Mon, 21 Nov 2016 20:31:51 GMT',
#  'expired': False,
#  'formattedLocation': 'Salt Lake City, UT',
#  'formattedLocationFull': 'Salt Lake City, UT',
#  'formattedRelativeTime': '4 days ago',
#  'indeedApply': True,
#  'jobkey': '95f00f008878c12d',
#  'jobtitle': 'Maintenance Technician/Planner',
#  'latitude': 40.758244,
#  'longitude': -111.89011,
#  'onmousedown': "indeed_clk(this,'9602');",
#  'snippet': 'Skill in electrical, <b>industrial</b> wiring; Read and understand <b>engineering</b> prints and schematics; Hoyt Archery Company, a premier manufacturer of archery products,...',
#  'source': 'Indeed',
#  'sponsored': False,
#  'state': 'UT',
#  'stations': '',
#  'url': 'http://www.indeed.com/viewjob?jk=95f00f008878c12d&qd=1vHU8bY0zJlP3i697aWcB75X8sGNGDwlMH1mcOLyc24WEcnmpaXnJU-e5l4ZFATyPXMe8ES_Uu649LjJwKcJE0DMV1kPL5XwkFiVFRNI-qmM6vJRdnBxKeL2d3av2ZWykIcIIFlGRLx7TeTnA7QD2w&indpubnum=336274463762899&atk=1b2gt5m4na55pfdj'}
